# %%
import pandas as pd

# Create a dataset containing duplicate rows
data = {
    "Name": ["Amit", "Riya", "Amit", "Neha", "Riya"],
    "Age": [20, 21, 20, 22, 21],
    "Marks": [85, 90, 85, 88, 90]
}

df = pd.DataFrame(data)

print("Original Dataset:")
print(df)
# Out:
# Original Dataset:
#    Name  Age  Marks
# 0  Amit   20     85
# 1  Riya   21     90
# 2  Amit   20     85
# 3  Neha   22     88
# 4  Riya   21     90

# %%
# Identify duplicate entries
print("\nDuplicate Rows:")
print(df[df.duplicated()])
# Out:
# Duplicate Rows:
#    Name  Age  Marks
# 2  Amit   20     85
# 4  Riya   21     90

# %%
# Remove all duplicate rows
df_no_duplicates = df.drop_duplicates()

print("\nDataset after removing duplicate rows:")
print(df_no_duplicates)
# Out:
# Dataset after removing duplicate rows:
#    Name  Age  Marks
# 0  Amit   20     85
# 1  Riya   21     90
# 3  Neha   22     88
