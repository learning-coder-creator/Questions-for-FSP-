# %%
from sklearn.preprocessing import LabelEncoder

data = ["Red", "Blue", "Green", "Blue"]

encoder = LabelEncoder()
encoded_data = encoder.fit_transform(data)

print(f"Original Categorical Data: {data}")
print(f"Encoded Numerical Labels:  {encoded_data.tolist()}")
# Out:
# Original Categorical Data: ['Red', 'Blue', 'Green', 'Blue']
# Encoded Numerical Labels:  [2, 0, 1, 0]
